# %% [markdown]
# <a href="https://colab.research.google.com/github/AbR04/BIS-LAB/blob/main/BIS_WEEK_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Define the Sphere function (objective function)
def sphere(x):
    return np.sum(x**2)

# Lévy flight function to generate new positions
def levy_flight(Lambda, dim):
    # Generate random Lévy distribution steps
    sigma = (np.math.gamma(1 + Lambda) * np.sin(np.pi * Lambda / 2) / np.math.gamma((1 + Lambda) / 2) * Lambda * np.pi)**(1 / Lambda)
    step = np.random.normal(0, sigma, dim)
    return step

# Cuckoo Search Algorithm
def cuckoo_search(num_nests, num_iterations, dim, p_a, Lambda=1.5):
    # Step 1: Initialize population of nests
    nests = np.random.uniform(-5, 5, (num_nests, dim))  # Initial population
    fitness = np.array([sphere(nest) for nest in nests])  # Evaluate fitness

    # Best nest initially
    best_nest_index = np.argmin(fitness)
    best_nest = nests[best_nest_index]
    best_fitness = fitness[best_nest_index]

    for iteration in range(num_iterations):
        # Step 2: Generate new solutions using Lévy flights
        new_nests = np.copy(nests)
        for i in range(num_nests):
            step = levy_flight(Lambda, dim)
            new_nests[i] = nests[i] + step  # Update nest position

            # Evaluate fitness of new solution
            new_fitness = sphere(new_nests[i])

            # Step 3: If the new solution is better, update the nest
            if new_fitness < fitness[i]:
                nests[i] = new_nests[i]
                fitness[i] = new_fitness

        # Step 4: Abandon the worst nests (randomly replace them)
        abandon_indices = np.argsort(fitness)[:int(p_a * num_nests)]  # Select worst nests
        nests[abandon_indices] = np.random.uniform(-5, 5, (len(abandon_indices), dim))  # Replace with random nests
        fitness[abandon_indices] = np.array([sphere(nest) for nest in nests[abandon_indices]])  # Evaluate new random nests

        # Update best nest
        best_nest_index = np.argmin(fitness)
        best_nest = nests[best_nest_index]
        best_fitness = fitness[best_nest_index]

        # Print the progress
        print(f"Iteration {iteration + 1}, Best Fitness: {best_fitness}")

    return best_nest, best_fitness

# Parameters
num_nests = 25
num_iterations = 100
dim = 5  # Dimensionality of the problem
p_a = 0.25  # Probability of discovering a nest

# Run the Cuckoo Search
best_solution, best_fitness = cuckoo_search(num_nests, num_iterations, dim, p_a)

print("\nBest Solution:", best_solution)
print("Best Fitness Value:", best_fitness)
# Out:
# Iteration 1, Best Fitness: 10.608596605888858
# Iteration 2, Best Fitness: 29.386219305684286
# Iteration 3, Best Fitness: 19.594362098331647
# Iteration 4, Best Fitness: 33.110056923061975
# Iteration 5, Best Fitness: 21.83785191300207
# Iteration 6, Best Fitness: 22.021024385973107
# Iteration 7, Best Fitness: 9.051144649896049
# Iteration 8, Best Fitness: 11.985057872736792
# Iteration 9, Best Fitness: 15.095812523342424
# Iteration 10, Best Fitness: 10.31135233436343
# Iteration 11, Best Fitness: 22.811167122887834
# Iteration 12, Best Fitness: 15.37304775080465
# Iteration 13, Best Fitness: 22.336610501254395
# Iteration 14, Best Fitness: 29.75685494522298
# Iteration 15, Best Fitness: 21.109809540327465
# Iteration 16, Best Fitness: 21.143576833653555
# Iteration 17, Best Fitness: 10.437401906730203
# Iteration 18, Best Fitness: 22.90492256377773
# Iteration 19, Best Fitness: 20.392941475618926
# Iteration 20, Best Fitness: 18.319476508095036
# Iteration 21, Best Fitness: 12.628412079270413
# Iteration 22, Best Fitness: 19.32313470882837
# Iteration 23, Best Fitness: 9.529930061242961
# Iteration 24, Best Fitness: 4.377057301333739
# Iteration 25, Best Fitness: 18.412558011458138
# Iteration 26, Best Fitness: 26.925903566565136
# Iteration 27, Best Fitness: 26.23924517038099
# Iteration 28, Best Fitness: 25.841135171836676
# Iteration 29, Best Fitness: 18.568859412727686
# Iteration 30, Best Fitness: 25.939170153103564
# Iteration 31, Best Fitness: 8.226346675397297
# Iteration 32, Best Fitness: 14.40683023265442
# Iteration 33, Best Fitness: 16.77749499944636
# Iteration 34, Best Fitness: 28.36192488534587
# Iteration 35, Best Fitness: 19.08877857538695
# Iteration 36, Best Fitness: 25.17984189678224
# Iteration 37, Best Fitness: 37.241928099546264
# Iteration 38, Best Fitness: 19.580065203249724
# Iteration 39, Best Fitness: 20.912210474318236
# Iteration 40, Best Fitness: 17.82313714000194
# Iteration 41, Best Fitness: 22.701355574318782
# Iteration 42, Best Fitness: 27.21448774290845
# Iteration 43, Best Fitness: 18.22949679431555
# Iteration 44, Best Fitness: 26.04347390799812
# Iteration 45, Best Fitness: 22.313984737574213
# Iteration 46, Best Fitness: 13.636676868575373
# Iteration 47, Best Fitness: 30.13208338202958
# Iteration 48, Best Fitness: 23.954472766952485
# Iteration 49, Best Fitness: 23.659250821167458
# Iteration 50, Best Fitness: 18.808757519218616
# Iteration 51, Best Fitness: 13.878720247127504
# Iteration 52, Best Fitness: 7.282086591613109
# Iteration 53, Best Fitness: 36.09179484600597
# Iteration 54, Best Fitness: 27.881231480211248
# Iteration 55, Best Fitness: 19.996232852734938
# Iteration 56, Best Fitness: 9.490203874668705
# Iteration 57, Best Fitness: 18.42066931486508
# Iteration 58, Best Fitness: 12.757126842882636
# Iteration 59, Best Fitness: 33.26045717212288
# Iteration 60, Best Fitness: 23.468560056823765
# Iteration 61, Best Fitness: 30.554145147593196
# Iteration 62, Best Fitness: 15.158034170630696
# Iteration 63, Best Fitness: 30.540801283617725
# Iteration 64, Best Fitness: 3.205450690236713
# Iteration 65, Best Fitness: 12.675643686855945
# Iteration 66, Best Fitness: 12.948650218413462
# Iteration 67, Best Fitness: 14.731116386040004
# Iteration 68, Best Fitness: 16.31820192192983
# Iteration 69, Best Fitness: 17.555205408241505
# Iteration 70, Best Fitness: 21.89842891177279
# Iteration 71, Best Fitness: 22.054485003187782
# Iteration 72, Best Fitness: 14.563948812753383
# Iteration 73, Best Fitness: 30.32406160912125
# Iteration 74, Best Fitness: 22.17998309554196
# Iteration 75, Best Fitness: 33.625787888714164
# Iteration 76, Best Fitness: 20.90611557524432
# Iteration 77, Best Fitness: 19.72842446990719
# Iteration 78, Best Fitness: 26.719504825415676
# Iteration 79, Best Fitness: 12.06530472394239
# Iteration 80, Best Fitness: 12.218616234224497
# Iteration 81, Best Fitness: 21.986412464260745
# Iteration 82, Best Fitness: 39.01959565387548
# Iteration 83, Best Fitness: 14.703416292228459
# Iteration 84, Best Fitness: 39.59887563399003
# Iteration 85, Best Fitness: 19.018988896262783
# Iteration 86, Best Fitness: 11.091575620951177
# Iteration 87, Best Fitness: 9.936556859619499
# Iteration 88, Best Fitness: 29.394081336728675
# Iteration 89, Best Fitness: 36.31041796317324
# Iteration 90, Best Fitness: 21.981629020320053
# Iteration 91, Best Fitness: 21.182317488510662
# Iteration 92, Best Fitness: 33.62094743016894
# Iteration 93, Best Fitness: 36.37828002003325
# Iteration 94, Best Fitness: 15.743776974098923
# Iteration 95, Best Fitness: 14.181010825928482
# Iteration 96, Best Fitness: 30.73371561568179
# Iteration 97, Best Fitness: 13.474165198314008
# Iteration 98, Best Fitness: 34.93116735475323
# Iteration 99, Best Fitness: 28.328175979667225
# Iteration 100, Best Fitness: 29.064106357217685
#
# Best Solution: [ 3.7147823   0.63690048 -0.06500062 -0.12289044 -3.85221098]
# Best Fitness Value: 29.064106357217685
# <ipython-input-9-94b513d59805>:10: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   sigma = (np.math.gamma(1 + Lambda) * np.sin(np.pi * Lambda / 2) / np.math.gamma((1 + Lambda) / 2) * Lambda * np.pi)**(1 / Lambda)

# %%
import numpy as np

# Define the Sphere function (objective function)
def sphere(x):
    return np.sum(x**2)

# Lévy flight function to generate new positions
def levy_flight(Lambda, dim):
    # Generate random Lévy distribution steps
    sigma = (np.math.gamma(1 + Lambda) * np.sin(np.pi * Lambda / 2) / np.math.gamma((1 + Lambda) / 2) * Lambda * np.pi)**(1 / Lambda)
    step = np.random.normal(0, sigma, dim)
    return step

# Cuckoo Search Algorithm
def cuckoo_search(num_nests, num_iterations, dim, p_a, Lambda=1.5):
    # Step 1: Initialize population of nests
    nests = np.random.uniform(-5, 5, (num_nests, dim))  # Initial population
    fitness = np.array([sphere(nest) for nest in nests])  # Evaluate fitness

    # Initialize the best nest and its fitness
    best_nest_index = np.argmin(fitness)
    best_nest = nests[best_nest_index]
    best_fitness = fitness[best_nest_index]

    for iteration in range(num_iterations):
        # Step 2: Generate new solutions using Lévy flights
        new_nests = np.copy(nests)
        for i in range(num_nests):
            step = levy_flight(Lambda, dim)
            new_nests[i] = nests[i] + step  # Update nest position

            # Evaluate fitness of new solution
            new_fitness = sphere(new_nests[i])

            # Step 3: If the new solution is better, update the nest
            if new_fitness < fitness[i]:
                nests[i] = new_nests[i]
                fitness[i] = new_fitness

        # Step 4: Abandon the worst nests (randomly replace them)
        abandon_indices = np.argsort(fitness)[:int(p_a * num_nests)]  # Select worst nests
        nests[abandon_indices] = np.random.uniform(-5, 5, (len(abandon_indices), dim))  # Replace with random nests
        fitness[abandon_indices] = np.array([sphere(nest) for nest in nests[abandon_indices]])  # Evaluate new random nests

        # Update the best solution found so far (ensure continuous tracking)
        # Find the index of the best nest after updates
        current_best_index = np.argmin(fitness)
        current_best_fitness = fitness[current_best_index]

        # Only update if the current best fitness is better than the previously found best
        if current_best_fitness < best_fitness:
            best_nest = nests[current_best_index]
            best_fitness = current_best_fitness

        # Print the progress
        print(f"Iteration {iteration + 1}, Best Fitness: {best_fitness}")

    return best_nest, best_fitness

# Parameters
num_nests = 25
num_iterations = 100
dim = 1  # Dimensionality of the problem
p_a = 0.25  # Probability of discovering a nest

# Run the Cuckoo Search
best_solution, best_fitness = cuckoo_search(num_nests, num_iterations, dim, p_a)

print("\nBest Solution:", best_solution)
print("Best Fitness Value:", best_fitness)
# Out:
# Iteration 1, Best Fitness: 0.0009762318787407783
# Iteration 2, Best Fitness: 0.0009762318787407783
# Iteration 3, Best Fitness: 0.0009762318787407783
# Iteration 4, Best Fitness: 0.0009762318787407783
# Iteration 5, Best Fitness: 0.0009762318787407783
# Iteration 6, Best Fitness: 0.0009762318787407783
# Iteration 7, Best Fitness: 0.0009762318787407783
# Iteration 8, Best Fitness: 0.0009762318787407783
# Iteration 9, Best Fitness: 0.0009762318787407783
# Iteration 10, Best Fitness: 0.0009762318787407783
# Iteration 11, Best Fitness: 0.0009762318787407783
# Iteration 12, Best Fitness: 0.0009762318787407783
# Iteration 13, Best Fitness: 0.0009762318787407783
# Iteration 14, Best Fitness: 0.0009762318787407783
# Iteration 15, Best Fitness: 0.0009762318787407783
# Iteration 16, Best Fitness: 0.0009762318787407783
# Iteration 17, Best Fitness: 0.0009762318787407783
# Iteration 18, Best Fitness: 0.0009762318787407783
# Iteration 19, Best Fitness: 0.0009762318787407783
# Iteration 20, Best Fitness: 0.0009762318787407783
# Iteration 21, Best Fitness: 0.0009762318787407783
# Iteration 22, Best Fitness: 0.0009762318787407783
# Iteration 23, Best Fitness: 0.0009762318787407783
# Iteration 24, Best Fitness: 0.0009762318787407783
# Iteration 25, Best Fitness: 0.0009762318787407783
# Iteration 26, Best Fitness: 0.0009762318787407783
# Iteration 27, Best Fitness: 0.0009762318787407783
# Iteration 28, Best Fitness: 0.0009762318787407783
# Iteration 29, Best Fitness: 0.0009762318787407783
# Iteration 30, Best Fitness: 0.0009762318787407783
# Iteration 31, Best Fitness: 0.0009762318787407783
# Iteration 32, Best Fitness: 0.0009762318787407783
# Iteration 33, Best Fitness: 0.0009762318787407783
# Iteration 34, Best Fitness: 0.0009762318787407783
# Iteration 35, Best Fitness: 0.0009762318787407783
# Iteration 36, Best Fitness: 0.0009762318787407783
# Iteration 37, Best Fitness: 0.0009762318787407783
# Iteration 38, Best Fitness: 0.0009762318787407783
# Iteration 39, Best Fitness: 0.0009762318787407783
# Iteration 40, Best Fitness: 0.0009762318787407783
# Iteration 41, Best Fitness: 0.0009762318787407783
# Iteration 42, Best Fitness: 0.0009762318787407783
# Iteration 43, Best Fitness: 0.0009762318787407783
# Iteration 44, Best Fitness: 0.0009762318787407783
# Iteration 45, Best Fitness: 0.0009762318787407783
# Iteration 46, Best Fitness: 0.0009762318787407783
# Iteration 47, Best Fitness: 0.0009762318787407783
# Iteration 48, Best Fitness: 0.0009762318787407783
# Iteration 49, Best Fitness: 0.0009762318787407783
# Iteration 50, Best Fitness: 0.0009762318787407783
# Iteration 51, Best Fitness: 0.0009762318787407783
# Iteration 52, Best Fitness: 0.0009762318787407783
# Iteration 53, Best Fitness: 0.0009762318787407783
# Iteration 54, Best Fitness: 0.0009762318787407783
# Iteration 55, Best Fitness: 0.0009762318787407783
# Iteration 56, Best Fitness: 0.0009762318787407783
# Iteration 57, Best Fitness: 0.0009762318787407783
# Iteration 58, Best Fitness: 0.0009762318787407783
# Iteration 59, Best Fitness: 0.0009762318787407783
# Iteration 60, Best Fitness: 0.0009762318787407783
# Iteration 61, Best Fitness: 0.0009762318787407783
# Iteration 62, Best Fitness: 0.0002337691483084152
# Iteration 63, Best Fitness: 0.0002337691483084152
# Iteration 64, Best Fitness: 0.0002337691483084152
# Iteration 65, Best Fitness: 0.0002337691483084152
# Iteration 66, Best Fitness: 0.0002337691483084152
# Iteration 67, Best Fitness: 0.0002337691483084152
# Iteration 68, Best Fitness: 0.0002337691483084152
# Iteration 69, Best Fitness: 0.0002337691483084152
# Iteration 70, Best Fitness: 0.0002337691483084152
# Iteration 71, Best Fitness: 0.0002337691483084152
# Iteration 72, Best Fitness: 0.0002337691483084152
# Iteration 73, Best Fitness: 0.0002337691483084152
# Iteration 74, Best Fitness: 0.0002337691483084152
# Iteration 75, Best Fitness: 0.0002337691483084152
# Iteration 76, Best Fitness: 0.0002337691483084152
# Iteration 77, Best Fitness: 0.0002337691483084152
# Iteration 78, Best Fitness: 0.0002337691483084152
# Iteration 79, Best Fitness: 0.0002337691483084152
# Iteration 80, Best Fitness: 0.0002337691483084152
# Iteration 81, Best Fitness: 0.0002337691483084152
# Iteration 82, Best Fitness: 0.0002337691483084152
# Iteration 83, Best Fitness: 0.0002337691483084152
# Iteration 84, Best Fitness: 0.0002337691483084152
# Iteration 85, Best Fitness: 0.0002337691483084152
# Iteration 86, Best Fitness: 0.0002337691483084152
# Iteration 87, Best Fitness: 0.0002337691483084152
# Iteration 88, Best Fitness: 0.0002337691483084152
# Iteration 89, Best Fitness: 0.0002337691483084152
# Iteration 90, Best Fitness: 0.0002337691483084152
# Iteration 91, Best Fitness: 0.0002337691483084152
# Iteration 92, Best Fitness: 0.0002337691483084152
# Iteration 93, Best Fitness: 0.0002337691483084152
# Iteration 94, Best Fitness: 0.0002337691483084152
# Iteration 95, Best Fitness: 0.0002337691483084152
# Iteration 96, Best Fitness: 0.0002337691483084152
# Iteration 97, Best Fitness: 0.0002337691483084152
# Iteration 98, Best Fitness: 0.0002337691483084152
# Iteration 99, Best Fitness: 0.0002337691483084152
# Iteration 100, Best Fitness: 0.0002337691483084152
#
# Best Solution: [-2.04111102]
# Best Fitness Value: 0.0002337691483084152
# <ipython-input-12-6f4ac4e0d3ba>:10: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   sigma = (np.math.gamma(1 + Lambda) * np.sin(np.pi * Lambda / 2) / np.math.gamma((1 + Lambda) / 2) * Lambda * np.pi)**(1 / Lambda)
